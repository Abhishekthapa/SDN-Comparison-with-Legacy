# %%
import matplotlib.pyplot as plt

import numpy as np

plt.rcParams['axes.labelsize'] = 20
plt.rcParams['font.weight']='bold'
plt.rcParams['font.size']=14
plt.rcParams['legend.fontsize'] = 10

# %%
#mdev of RTT for 5,10,20,30,50,100 packets

fig, ax = plt.subplots()


rtt_mdev=[0.027,0.043,0.070,0.052,0.036,0.052,]
packets=[5,10,20,30,50,100]
l1, =plt.plot(packets,rtt_mdev)


rtt_mdev=[0.025,0.066,0.057,0.062,0.058,0.067]
packets=[5,10,20,30,50,100]
l2, =plt.plot(packets,rtt_mdev)
plt.legend((l1, l2), ('h1 to h2', 'h2 to h1'), loc='upper right')
plt.xlabel('No. of packets')
plt.ylabel('Standard Deviation of RTT')
plt.title('RTT Variance ')
# Out:
# Text(0.5, 1.0, 'RTT Variance ')

# %%
barWidth = 0.25

# set height of bar
bars1 = [0.153,0.143,0.147,0.151,0.124,0.079]
bars2 = [0.214,0.268,0.471,0.443,0.309,0.401]

# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
 
# Make the plot
plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='min. RTT')
plt.bar(r2, bars2, color='#2d7f5e', width=barWidth, edgecolor='white', label='max. RTT')

# Add xticks on the middle of the group bars
plt.xlabel('No. of packets')
plt.ylabel('Time taken in ms')
plt.xticks([r + barWidth/2 for r in range(len(bars1))], ['5', '10', '20', '30', '50','100'])
 
#plt.savefig('PTR_transit.png')
plt.title('Min. and Max. RTT (h1 to h2)')
plt.legend()
plt.show()

# %%
barWidth = 0.25

bars1 = [0.178,0.130,0.141,0.075,0.106,0.066]
bars2 = [0.237,0.362,0.343,0.412,0.480,0.495]
 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
 
# Make the plot
plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='min. RTT')
plt.bar(r2, bars2, color='#2d7f5e', width=barWidth, edgecolor='white', label='max. RTT')

# Add xticks on the middle of the group bars
plt.xlabel('No. of packets')
# plt.ylabel('Time taken in ms', fontweight='bold')
plt.xticks([r + barWidth/2 for r in range(len(bars1))], ['5', '10', '20', '30', '50','100'])
 
#plt.savefig('PTR_transit.png')
plt.title('Min. and Max. RTT (h2 to h1)')
plt.legend()
plt.show()

# %%
barWidth = 0.25
 
# set height of bar
bars1 = [4001,8999,19025,29023,49029,99043]
bars2 = [4005,9009,19003,29012,49024,99055]
 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
 
# Make the plot
plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='h1 to h2')
plt.bar(r2, bars2, color='#557f2d', width=barWidth, edgecolor='white', label='h2 to h1')
 
# Add xticks on the middle of the group bars
plt.xlabel('No. of packets', fontweight='bold')
plt.ylabel('Time taken in ms', fontweight='bold')
plt.xticks([r + barWidth/2 for r in range(len(bars1))], ['5', '10', '20', '30', '50','100'])
plt.title('Packet Transmission Time')
 
#plt.savefig('PTR_transit.png')
plt.legend()
plt.show()

# %%
barWidth = 0.25
 
# set height of bar
bars1 = [4001,8999,19025,29023,49029,99043]
bars2 = [4017,8999,19001,29024,49001,99061]
 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
 
# Make the plot
plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='Legacy')
plt.bar(r2, bars2, color='#557f2d', width=barWidth, edgecolor='white', label='SDN')
 
# Add xticks on the middle of the group bars
plt.xlabel('No. of packets', fontweight='bold')
plt.ylabel('Time taken in ms', fontweight='bold')
plt.xticks([r + barWidth/2 for r in range(len(bars1))], ['5', '10', '20', '30', '50','100'])
plt.title('Packet Transmission Time')
 
#plt.savefig('PTR_transit.png')
plt.legend()

# %%
sample = [0.027,0.043,0.070,0.052,0.036,0.052,0.025,0.066,0.057,0.062,0.058,0.067]

sample_mean = stat.mean(sample)
# two_tailed test
sample_size = len(sample)

t_critical = stats.t.ppf(q = 0.975, df=sample_size-1) 
# sample_stdev = sample.std(ddof=1)    # Get the sample standard deviation
sample_stdev = stat.pstdev(sample)

sigma = sample_stdev/math.sqrt(sample_size)  # Standard deviation estimate
margin_of_error = t_critical * sigma

confidence_interval = (sample_mean - margin_of_error,
                       sample_mean + margin_of_error) 
print(sample_mean)
print(t_critical)
print(confidence_interval)
