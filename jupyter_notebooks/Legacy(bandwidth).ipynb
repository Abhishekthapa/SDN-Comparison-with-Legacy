# %%
import matplotlib.pyplot as plt

import numpy as np

plt.rcParams['axes.labelsize'] = 20
plt.rcParams['font.weight']='bold'
plt.rcParams['font.size']=14
plt.rcParams['legend.fontsize'] = 10

# %%
barWidth = 0.25
 
# set height of bar
#transit AS, within AS, neighbouring(0 to 1), neighouring (0 to 2)
bars1 = [19.5, 21.8, 20.8, 21.7]
bars2 = [21.7, 28.7, 25, 23]

 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]



# Make the plot
plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label="Legacy")
plt.bar(r2, bars2, color='#2d7f5e', width=barWidth, edgecolor='white', label="SDN")

# Add xticks on the middle of the group bars
plt.ylabel('Bandwidth in Gigabits/sec', fontweight='bold')

plt.xticks([r + barWidth/2 for r in range(len(bars))], ['AS65000/SDN as transit', 'Within AS65000/SDN', 'Neighbouring AS(h1)',
                                                        'Neighbouring AS(h2)'],
          rotation='vertical')
 
#plt.savefig('minmaxRTT.png')
plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1))
plt.show()
