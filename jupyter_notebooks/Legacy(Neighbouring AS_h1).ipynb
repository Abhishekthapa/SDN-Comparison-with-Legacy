# %%
import matplotlib.pyplot as plt

import numpy as np

plt.rcParams['axes.labelsize'] = 20
plt.rcParams['font.weight']='bold'
plt.rcParams['font.size']=14
plt.rcParams['legend.fontsize'] = 10

# %% [markdown]
# We first look between AS65000 and AS65001

# %%
#between 65000 and 65001(h1 and h3)
#mdev of RTT for 5,10,20,30,50,100 packets

fig, ax = plt.subplots()


rtt_mdev=[0.033,0.041,0.042,0.034,0.068,0.067]
packets=[5,10,20,30,50,100]
l1, =plt.plot(packets,rtt_mdev)


rtt_mdev=[0.018,0.021,0.031,0.037,0.052,0.033]
packets=[5,10,20,30,50,100]
l2, =plt.plot(packets,rtt_mdev)
plt.legend((l1, l2), ('h1 to h3', 'h3 to h1'), loc='upper right')
plt.xlabel('No. of packets')
plt.ylabel('Standard Deviation of RTT')
plt.title('RTT Variance ')
# Out:
# Text(0.5, 1.0, 'RTT Variance ')

# %%
#between 65000 and 65001(h1 and h3)
#min and max RTT

barWidth = 0.25
 
# set height of bar
bars1 = [0.128,0.117,0.111,0.082,0.091,0.072]
bars2 = [0.221,0.244,0.294,0.258,0.423,0.589]

 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]



# Make the plot
plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='min. RTT')
plt.bar(r2, bars2, color='#2d7f5e', width=barWidth, edgecolor='white', label='max. RTT')

# Add xticks on the middle of the group bars
plt.xlabel('No. of packets')
plt.ylabel('Time taken in ms')
plt.xticks([r + barWidth/2 for r in range(len(bars1))], ['5', '10', '20', '30', '50','100'])
 
#plt.savefig('minmaxRTT.png')
plt.title('Min. and Max. RTT (h1 to h3)')
plt.legend(loc='upper left')
plt.show()

# %%
#between 65000 and 65001(h1 and h3)
#min and max RTT

barWidth = 0.25
 
# set height of bar
bars1 = [0.137,0.112,0.129,0.106,0.057,0.056]
bars2 = [0.168,0.169,0.247,0.252,0.375,0.273]

 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]



# Make the plot
plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='min. RTT')
plt.bar(r2, bars2, color='#2d7f5e', width=barWidth, edgecolor='white', label='max. RTT')

# Add xticks on the middle of the group bars
plt.xlabel('No. of packets')
# plt.ylabel('Time taken in ms', fontweight='bold')
plt.xticks([r + barWidth/2 for r in range(len(bars1))], ['5', '10', '20', '30', '50','100'])
 
#plt.savefig('minmaxRTT.png')
plt.title('Min. and Max. RTT (h3 to h1)')
plt.legend(loc='upper left')
plt.show()

# %%
#between 65000 and 65001(h1 and h3)
barWidth = 0.25
 
# set height of bar
bars1 = [4003,9026,18999,29003,49033,99100]
bars2 = [3997,8998,19004,29025,49050,99054]
 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
 
# Make the plot
plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='h1')
plt.bar(r2, bars2, color='#557f2d', width=barWidth, edgecolor='white', label='h3 to h1')
 
# Add xticks on the middle of the group bars
plt.xlabel('No. of packets', fontweight='bold')
plt.ylabel('Time taken in ms', fontweight='bold')
plt.xticks([r + barWidth/2 for r in range(len(bars1))], ['5', '10', '20', '30', '50','100'])
plt.title('Packet Transmission Time')
 
#plt.savefig('PTR_transit.png')
plt.legend()
plt.show()

# %% [markdown]
# Now we look between host h1 and h4

# %%
#between 65000 and 65001(h1 and h4)
#mdev of RTT for 5,10,20,30,50,100 packets

fig, ax = plt.subplots()


rtt_mdev=[0.031,0.081,0.055,0.098,0.070,0.039]
packets=[5,10,20,30,50,100]
l1, =plt.plot(packets,rtt_mdev)


rtt_mdev=[0.032,0.052,0.081,0.116,0.064,0.073]
packets=[5,10,20,30,50,100]
l2, =plt.plot(packets,rtt_mdev)
plt.legend((l1, l2), ('h1 to h4', 'h4 to h1'), loc='upper right')
plt.xlabel('No. of packets')
plt.ylabel('Standard Deviation of RTT')
plt.title('RTT Variance ')
# Out:
# Text(0.5, 1.0, 'RTT Variance ')

# %%
#between 65000 and 65001(h1 and h4)
#min and max RTT

barWidth = 0.25
 
# set height of bar
bars1 = [0.149,0.131,0.059,0.068,0.129,0.137]
bars2 = [0.223,0.433,0.341,0.627,0.552,0.288]

 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]



# Make the plot
plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='min. RTT')
plt.bar(r2, bars2, color='#2d7f5e', width=barWidth, edgecolor='white', label='max. RTT')

# Add xticks on the middle of the group bars
plt.xlabel('No. of packets')
# plt.ylabel('Time taken in ms', fontweight='bold')
plt.xticks([r + barWidth/2 for r in range(len(bars1))], ['5', '10', '20', '30', '50','100'])
 
#plt.savefig('minmaxRTT.png')
plt.title('Min. and Max. RTT (h1 to h4)')
plt.legend(loc='upper left')
plt.show()

# %%
#between 65000 and 65001(h1 and h4)
#min and max RTT

barWidth = 0.25
 
# set height of bar
bars1 = [0.215,0.079,0.169,0.067,0.078,0.098]
bars2 = [0.285,0.299,0.534,0.692,0.502,0.591]

 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]



# Make the plot
plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='min. RTT')
plt.bar(r2, bars2, color='#2d7f5e', width=barWidth, edgecolor='white', label='max. RTT')

# Add xticks on the middle of the group bars
plt.xlabel('No. of packets', fontweight='bold')
plt.ylabel('Time taken in ms', fontweight='bold')
plt.xticks([r + barWidth/2 for r in range(len(bars1))], ['5', '10', '20', '30', '50','100'])
 
#plt.savefig('minmaxRTT.png')
plt.title('Min. and Max. RTT (h4 to h1)')
plt.legend(loc='upper left')
plt.show()

# %%
#between 65000 and 65001(h1 and h3)
barWidth = 0.25
 
# set height of bar
bars1 = [4005,9005,19008,29028,49030,99064]
bars2 = [4008,9002,19029,29018,49026,99056]
 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
 
# Make the plot
plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='h1 to h4')
plt.bar(r2, bars2, color='#557f2d', width=barWidth, edgecolor='white', label='h4 to h1')
 
# Add xticks on the middle of the group bars
plt.xlabel('No. of packets', fontweight='bold')
plt.ylabel('Time taken in ms', fontweight='bold')
plt.xticks([r + barWidth/2 for r in range(len(bars1))], ['5', '10', '20', '30', '50','100'])
plt.title('Packet Transmission Time')
 
#plt.savefig('PTR_transit.png')
plt.legend()
plt.show()

# %% [markdown]
# So far we looked into different hosts betn 65000 and 65001
# Now we look between 65000 and 65002
