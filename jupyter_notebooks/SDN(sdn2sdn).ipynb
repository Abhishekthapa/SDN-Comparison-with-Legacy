# %%
import matplotlib.pyplot as plt

import numpy as np

plt.rcParams['axes.labelsize'] = 20
plt.rcParams['font.weight']='bold'
plt.rcParams['font.size']=14
plt.rcParams['legend.fontsize'] = 10

# %%
#mdev of RTT for 5,10,20,30,50,100 packets
#SDN to SDN(h3 and h4)

fig, ax = plt.subplots()


rtt_mdev=[0.002,0.011,0.011,0.012,0.032,0.020]
packets=[5,10,20,30,50,100]
l1, =plt.plot(packets,rtt_mdev)


rtt_mdev=[0.144,0.013,0.044,0.017,0.021,0.017]
packets=[5,10,20,30,50,100]
l2, =plt.plot(packets,rtt_mdev)
plt.legend((l1, l2), ('h3 to h4', 'h4 to h3'), loc='upper right')
plt.xlabel('No. of packets')
plt.title('RTT Variance ')
# Out:
# Text(0.5, 1.0, 'RTT Variance ')

# %%
barWidth = 0.25
 
# set height of bar
bars1 = [0.060,0.056,0.053,0.053,0.051,0.050]
bars2 = [0.065,0.071,0.082,0.089,0.257,0.174]

 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]


# Make the plot
plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='min. RTT')
plt.bar(r2, bars2, color='#2d7f5e', width=barWidth, edgecolor='white', label='max. RTT')

# Add xticks on the middle of the group bars
plt.xlabel('No. of packets')
plt.ylabel('Time taken in ms')
plt.xticks([r + barWidth/2 for r in range(len(bars1))], ['5', '10', '20', '30', '50','100'])
 
#plt.savefig('PTR_transit.png')
plt.title('Min. and Max. RTT (h3 to h4)')
plt.legend(loc='upper left')
plt.show()

# %%
barWidth = 0.25
 
# set height of bar
bars1 = [0.063,0.055,0.051,0.053,0.046,0.051]
bars2 = [0.434,0.089,0.239,0.123,0.200,0.165]

 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]


# Make the plot
plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='min. RTT')
plt.bar(r2, bars2, color='#2d7f5e', width=barWidth, edgecolor='white', label='max. RTT')

# Add xticks on the middle of the group bars
plt.xlabel('No. of packets')
# plt.ylabel('Time taken in ms', fontweight='bold')
plt.xticks([r + barWidth/2 for r in range(len(bars1))], ['5', '10', '20', '30', '50','100'])
 
#plt.savefig('PTR_transit.png')
plt.title('Min. and Max. RTT (h4 to h3)')
plt.legend(loc='upper right')
plt.show()

# %%
barWidth = 0.25
 
# set height of bar
bars1 = [4000,8996,18997,29002,49019,99029]
bars2 = [3999,9011,19014,29000,49050,99009]
 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
 
# Make the plot
plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='h3 to h4')
plt.bar(r2, bars2, color='#557f2d', width=barWidth, edgecolor='white', label='h4 to h3')
 
# Add xticks on the middle of the group bars
plt.xlabel('No. of packets', fontweight='bold')
plt.ylabel('Time taken in ms', fontweight='bold')
plt.xticks([r + barWidth/2 for r in range(len(bars1))], ['5', '10', '20', '30', '50','100'])
plt.title('Packet Transmission Time')
 
#plt.savefig('PTR_transit.png')
plt.legend()
plt.show()

# %%
barWidth = 0.25
 
# set height of bar

bars1 = [4003,9001,19009,29009,49023,99078]
bars2 = [4000,8996,18997,29002,49019,99029]
 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
 
# Make the plot
plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='Legacy')
plt.bar(r2, bars2, color='#557f2d', width=barWidth, edgecolor='white', label='SDN')
 
# Add xticks on the middle of the group bars
plt.xlabel('No. of packets', fontweight='bold')
plt.ylabel('Time taken in ms', fontweight='bold')
plt.xticks([r + barWidth/2 for r in range(len(bars1))], ['5', '10', '20', '30', '50','100'])
plt.title('Packet Transmission Time')
 
#plt.savefig('PTR_transit.png')
plt.legend()
plt.show()
